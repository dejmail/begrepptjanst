# %% [markdown]
# # Test RAW SQL Queries

# %%
from sqlalchemy import create_engine, MetaData
from sqlalchemy.sql import select

import pandas as pd
#from django.db import connection, transaction

# %%
cnx = create_engine('sqlite:///ordlist_databas.sqlite3', echo=True)
meta = MetaData()
conn = cnx.connect()
# Out:
# 2020-02-18 09:53:48,066 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2020-02-18 09:53:48,070 INFO sqlalchemy.engine.base.Engine ()
# 2020-02-18 09:53:48,074 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2020-02-18 09:53:48,074 INFO sqlalchemy.engine.base.Engine ()

# %%
result = cnx.engine.execute("SELECT begrepp_kontext,\
begrepp_version_nummer,\
definition,\
externt_id,\
externt_register,\
status,\
term,\
utländsk_definition,\
utländsk_term,\
vgr_id,\
beställare_id,\
synonym from [ordbok_begrepp] JOIN ordbok_synonym ON [ordbok_begrepp].id = ordbok_synonym.begrepp_id")
# Out:
# 2020-02-18 10:07:21,513 INFO sqlalchemy.engine.base.Engine SELECT begrepp_kontext,begrepp_version_nummer,definition,externt_id,externt_register,status,term,utländsk_definition,utländsk_term,vgr_id,beställare_id,synonym from [ordbok_begrepp] JOIN ordbok_synonym ON [ordbok_begrepp].id = ordbok_synonym.begrepp_id
# 2020-02-18 10:07:21,513 INFO sqlalchemy.engine.base.Engine ()

# %% [raw]
# SELECT OrderNumber, TotalAmount, FirstName, LastName, City, Country
#   FROM [Order] JOIN Customer
#     ON [Order].CustomerId = Customer.Id

# %%
result.fetchall()
# Out:
# [('Inte definierad', '2017-10-27 00:00:00', 'paket av hälso- och sjukvårdaktiviteter', 'Inte definierad', 'Bilaga 1 FVM upphandling', 'Klar', 'aktivitetspaket', 'Inte definierad', 'Inte definierad', 'Inte definierad', 1, 'Inte definierad'),
#  ('För att få ta del av ospärrade uppgifter hos en annan vårdenhet eller vårdprocess krävs att användaren gör ett aktivt val. Det innebär att användaren ... (114 characters truncated) ... fter ska användaren göra ett aktivt val i journalsystemet för att bekräfta bedömningen. Det aktiva valet ska\nloggas för att dokumentera bedömningen.', '2020-02-17 15:56:40', 'särskild åtgärd för att få tillgång till del av patientjournal som inte visas när den öppnas efter sökning ', 'Inte definierad', 'Inte definierad', 'Klar', 'aktivt val', 'Inte definierad', 'Inte definierad', 'Inte definierad', 1, 'Inte definierad'),
# ...

# %%
#from sqlalchemy import text

#sql = text('select name from penguins')
#result = db.engine.execute(sql)
#names = [row[0] for row in result]
#print names
